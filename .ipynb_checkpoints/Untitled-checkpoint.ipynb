# %%
import subprocess

while True:
    test = subprocess.Popen(["ping", "-c", "1", "google.com"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
    print(test.stdout.read().decode('utf-8'))
# Out:
# PING google.com (216.58.197.174): 56 data bytes
# 64 bytes from 216.58.197.174: icmp_seq=0 ttl=116 time=4.827 ms
#
# --- google.com ping statistics ---
# 1 packets transmitted, 1 packets received, 0.0% packet loss
# round-trip min/avg/max/stddev = 4.827/4.827/4.827/0.000 ms
#
# PING google.com (216.58.197.174): 56 data bytes
# 64 bytes from 216.58.197.174: icmp_seq=0 ttl=116 time=4.487 ms
#
# --- google.com ping statistics ---
# 1 packets transmitted, 1 packets received, 0.0% packet loss
# round-trip min/avg/max/stddev = 4.487/4.487/4.487/0.000 ms
#
# PING google.com (216.58.197.174): 56 data bytes
# 64 bytes from 216.58.197.174: icmp_seq=0 ttl=116 time=4.514 ms
#
# --- google.com ping statistics ---
# 1 packets transmitted, 1 packets received, 0.0% packet loss
# round-trip min/avg/max/stddev = 4.514/4.514/4.514/0.000 ms
#
# PING google.com (216.58.197.174): 56 data bytes
# 64 bytes from 216.58.197.174: icmp_seq=0 ttl=116 time=4.878 ms
#
# --- google.com ping statistics ---
# ...
